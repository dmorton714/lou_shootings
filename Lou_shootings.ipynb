# %% [markdown]
# <a href="https://colab.research.google.com/github/dmorton714/lou_shootings/blob/main/Lou_shootings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
import json
import requests

# %% [markdown]
# https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/Louisville_Metro_KY_Crime_Data_2022/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson

# %%
response = requests.get("https://services1.arcgis.com/79kfd2K6fskCAkyg/arcgis/rest/services/Louisville_Metro_KY_Crime_Data_2022/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson")
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'type': 'FeatureCollection', 'properties': {'exceededTransferLimit': True}, 'features': [{'type': 'Feature', 'id': 1, 'geometry': None, 'properties': {'INCIDENT_NUMBER': '80-22-000221', 'DATE_REPORTED': '2022-01-02 02:12:00', 'DATE_OCCURED': '2022-01-02 02:09:00', 'BADGE_ID': '5115            ', 'CRIME_TYPE': 'ASSAULT', 'UOR_DESC': 'ASSAULT - 4TH DEGREE (DOMESTIC VIOLENCE) MINOR INJURY', 'NIBRS_CODE': '13B', 'UCR_HIERARCHY': 'PART II', 'ATT_COMP': 'COMPLETED', 'LMPD_DIVISION': '7TH DIVISION', 'LMPD_BEAT': '736', 'PREMISE_TYPE': 'RESIDENCE / HOME                             ', 'BLOCK_ADDRESS': '3600 BLOCK BRIARCLIFF CT                                    ', 'City': 'LOUISVILLE', 'ZIP_CODE': '40219', 'ObjectId': 1}}, {'type': 'Feature', 'id': 2, 'geometry': None, 'properties': {'INCIDENT_NUMBER': '80-22-000173', 'DATE_REPORTED': '2022-01-01 19:45:00', 'DATE_OCCURED': '2022-01-01 19:00:00', 'BADGE_ID': '5222            ', 'CRIME_TYPE': 'VANDALISM', 'UOR_DESC': 'CRIMINAL MISCHIEF-3RD DEG
# ...
